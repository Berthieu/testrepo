# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# #My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tokinirina Jean Berthieu Rakotomamonjy**<br>
# Modeling

# %% [markdown]
# *I am interested in data science because data science leads us to the future and I like to analyze and predict.*

# %% [markdown]
# ### Code is just function to add 2 numbers

# %%
def add_two_number(a,b):
    return a + b

a = 2
b = 3
result = add_two_number(a,b)
print(f"a + b = {result}")
# Out:
# a + b = 5

# %% [markdown]
# 1. Need to work
# 2. Intelligent
#
# - Bulleted Item 1
# - Bulleted Item 2
#
# ![IBM.jpg](attachment:529ba7c5-fe06-4949-834e-a32382159ca5.jpg)
